# %%
from molSimplify.Informatics.jupyter_vis import view_xyz

# %%
filename = '../../tests/refs/example_5.xyz'
view_xyz(filename,w=700,h=700)
# Out:
# <div id="3dmolviewer_156816920347"  style="position: relative; width: 700px; height: 700px">
#         <p id="3dmolwarning_156816920347" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab.  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_156816920347 = null;
# ...

# %%
filename1 = '../../tests/refs/example_5.xyz'
filename2 = '../../tests/refs/example_1.xyz'
filenames = [filename1, filename2]
view_xyz(filenames,w=400,h=400,labels=False)
# Out:
# <div id="3dmolviewer_156816921533"  style="position: relative; width: 800px; height: 400px">
#         <p id="3dmolwarning_156816921533" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab.  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_156816921533 = null;
# ...

# %%
filenames3 = filenames * 5
print(filenames3)
view_xyz(filenames3,w=180,h=180,labelsize=25,columns=5)
# Out:
# ['../../tests/refs/example_5.xyz', '../../tests/refs/example_1.xyz', '../../tests/refs/example_5.xyz', '../../tests/refs/example_1.xyz', '../../tests/refs/example_5.xyz', '../../tests/refs/example_1.xyz', '../../tests/refs/example_5.xyz', '../../tests/refs/example_1.xyz', '../../tests/refs/example_5.xyz', '../../tests/refs/example_1.xyz']
# <div id="3dmolviewer_156816882681"  style="position: relative; width: 900px; height: 360px">
#         <p id="3dmolwarning_156816882681" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab.  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
# ...
